# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')


plt.style.use("fivethirtyeight")
# %matplotlib inline

# %%
df = pd.read_csv('/content/IRIS.csv')
train = pd.read_csv('/content/IRIS.csv')
test = pd.read_csv('/content/IRIS.csv')
train.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# @title Sepal and petal dimensions

import matplotlib.pyplot as plt
plt.scatter(train['sepal_length'], train['sepal_width'], c=train['petal_length'], cmap='viridis')
plt.xlabel('Sepal Length')
_ = plt.ylabel('Sepal Width')

# %%
# @title Sepal Length vs Petal Length

import matplotlib.pyplot as plt
sns.regplot(x='sepal_length', y='petal_length', data=df)
plt.xlabel('Sepal Length')
_ = plt.ylabel('Petal Length')

# %%
# @title species

from matplotlib import pyplot as plt
import seaborn as sns
train.groupby('species').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
x=df.drop("species",axis=1)
y=df["species"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_lr=lr.predict(x_test)

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
print(classification_report(y_test,y_pred_lr))
print(accuracy_score(y_test,y_pred_lr))
print(confusion_matrix(y_test,y_pred_lr))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        17
# Iris-versicolor       1.00      0.93      0.97        15
#  Iris-virginica       0.93      1.00      0.96        13
#
#        accuracy                           0.98        45
#       macro avg       0.98      0.98      0.98        45
#    weighted avg       0.98      0.98      0.98        45
#
# 0.9777777777777777
# [[17  0  0]
#  [ 0 14  1]
#  [ 0  0 13]]

# %%
# prompt:

print(df.shape)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn=knn.predict(x_test)

# %%
print(classification_report(y_test,y_pred_knn))
print(accuracy_score(y_test,y_pred_knn))
print(confusion_matrix(y_test,y_pred_knn))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        17
# Iris-versicolor       1.00      1.00      1.00        15
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
#
# 1.0
# [[17  0  0]
#  [ 0 15  0]
#  [ 0  0 13]]

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf=rf.predict(x_test)

# %%
print(classification_report(y_test,y_pred_rf))
print(accuracy_score(y_test,y_pred_rf))
print(confusion_matrix(y_test,y_pred_rf))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        17
# Iris-versicolor       1.00      0.93      0.97        15
#  Iris-virginica       0.93      1.00      0.96        13
#
#        accuracy                           0.98        45
#       macro avg       0.98      0.98      0.98        45
#    weighted avg       0.98      0.98      0.98        45
#
# 0.9777777777777777
# [[17  0  0]
#  [ 0 14  1]
#  [ 0  0 13]]

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dt=dt.predict(x_test)

# %%
print(classification_report(y_test,y_pred_dt))
print(accuracy_score(y_test,y_pred_dt))
print(confusion_matrix(y_test,y_pred_dt))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        17
# Iris-versicolor       0.93      0.93      0.93        15
#  Iris-virginica       0.92      0.92      0.92        13
#
#        accuracy                           0.96        45
#       macro avg       0.95      0.95      0.95        45
#    weighted avg       0.96      0.96      0.96        45
#
# 0.9555555555555556
# [[17  0  0]
#  [ 0 14  1]
#  [ 0  1 12]]

# %%
print('iris flower classification is completed')
# Out:
# iris flower classification is completed
